# %% [markdown]
# # 演習問題12

# %%
import numpy as np
import scipy.stats as stats
from matplotlib import pyplot as plt
import seaborn as sns; sns.set() # sns.set() ==> グラフの見た目をseabornに合わせる

# %% [markdown]
# ## Xb = (X1 + X2 + ... + Xn) / n を作る

# %%
n = 10   # 互いに独立なn個の確率変数X1, X2, X3, ..., Xnの個数
N = 500  # Xnのサイズ

X = np.random.normal(loc=30, scale=500, size=(n, N))

# %%
Xb = np.mean(X, axis=0)  # 列ごとの平均

# %%
# mu = μ  
print('mu: {}'.format(np.mean(Xb)))

# sigma2 = σ^2/n
print('sigma2: {}'.format(np.var(Xb)))
# Out:
# mu: 39.82741056350306
# sigma2: 26549.607763739503

# %% [markdown]
# ## 正規性の確認

# %%
# Q-Qプロット
stats.probplot(Xb, dist="norm", plot=plt)
plt.show()

# %%
sns.distplot(Xb)
